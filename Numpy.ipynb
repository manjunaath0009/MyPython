# %%
import numpy as np # type: ignore

arr = np.array([1, 2, 3, 4])

print(arr[0])
# Out:
# 1

# %%
arr = np.array([1, 2, 3, 4])

print(arr[2] + arr[3])
# Out:
# 7

# %%
from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

random.shuffle(arr)

print(arr)
# Out:
# [5 4 2 1 3]

# %%
from numpy import random

x = random.normal(size=(2, 3))

print(x)
# Out:
# [[-0.32967336  0.51723578  0.69871241]
#  [-0.80476395  0.16986447  0.82092609]]

# %%
from numpy import random

x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 1.42038942 -0.01290494  0.96605636]
#  [-1.45449988  1.62372162 -1.08829783]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

sns.histplot([0, 1, 2, 3, 4, 5])

plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18908\1803953371.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18908\1803953371.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

# %%
from numpy import random

x = random.poisson(lam=2, size=10)

print(x)
# Out:
# [2 6 4 2 1 4 0 1 3 4]

# %%
x = [1, 2, 3, 4]
y = [4, 5, 6, 7]
z = []

for i, j in zip(x, y):
  z.append(i + j)
print(z)
# Out:
# [5, 7, 9, 11]

# %%
import numpy as np

x = [1, 2, 3, 4]
y = [4, 5, 6, 7]
z = np.add(x, y)

print(z)
# Out:
# [ 5  7  9 11]

# %%
import numpy as np

def myadd(x, y):
  return x+y

myadd = np.frompyfunc(myadd, 2, 1)

print(myadd([1, 2, 3, 4], [5, 6, 7, 8]))
# Out:
# [6 8 10 12]

# %%
import numpy as np

arr = np.trunc([-3.1666, 3.6667])

print(arr)
# Out:
# [-3.  3.]

# %%
import numpy as np
a = np.array([[1., 2.], [3., 4.]])
x = np.array([1, 2, 3, 4])
y = np.array([4, 5, 6, 7])
#z = np.array(x, y)
z = np.prod(x,y, axis=1)
print(z)
prod1 = np.prod(a, axis=1)

print(prod1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 6
#       4 y = np.array([4, 5, 6, 7])
#       5 #z = np.array(x, y)
# ----> 6 z = np.prod(x,y, axis=1)
#       7 print(z)
#       8 prod1 = np.prod(a, axis=1)
#
# TypeError: prod() got multiple values for argument 'axis'
