# %%
#Matplotlib is a plotting library for the python programming language and numerical extension with the help of numpy.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
# ****************Major pros****************
# Generally easy to get started with simpler plots
# Support for custom label and texts
# Great control of every element in a figure 
# High quality of output in any format 
# Very customizable

# %%
from cmath import rect
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
# plt.show()
# %matplotlib inline 

import numpy as np 

x=np.arange(0,10)
y=np.arange(11,21)

#plt.scatter(x,y,c="g")
plt.xlabel("X Axis",c='r')
plt.ylabel("Y Axis",c='r')
plt.title("First Plot diagram of Manjunaath")
plt.savefig("First_Plot_Manjunaath.jpg")
y=x*x
#plt.plot(x,y,'ro--')s
plt.plot(x,y,linestyle='dashed',linewidth='2',markersize=10)

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'b')
plt.subplot(2,2,2)
plt.plot(x,y,'r')
plt.subplot(2,2,3)
plt.plot(x,y,'k')

# %%
x=np.arange(1,100)
y=np.sin(x)
plt.title("Sine Diagram")
plt.xlabel("X Axis - random values")
plt.ylabel("Y Axis - Sin values")
plt.plot(x,y)

# %%
x=np.arange(1,100)
y_sin=np.sin(x)
y_cos=np.cos(x)
y_tan=np.tan(x)
y_sinc=np.sinc(x)
plt.title("Sine Diagram")
plt.xlabel("X Axis - random values")
plt.ylabel("Y Axis - Sin values")
plt.plot(x,y,c='r')

# %%
plt.subplot(1,2,1) #1 Row and 2 Columns printing of diagram
plt.plot(x,y_sin)
plt.title("Sine Waves")
plt.subplot(1,2,2)
print()
plt.plot(x,y_cos)
plt.title("Cosine Waves")
# Out:
# Text(0.5, 1.0, 'Cosine Waves')

# %%
x1=[1,2,3]
y1=[4,5,6]

x2=[4,5,6]
y2=[40,50,60]

plt.bar(x1,y1)

plt.bar(x2,y2)

plt.title("Bar Chart")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
x=np.array([1,2,3,4,5,6,1,2,3,5,1,2,3,5])
plt.hist(x,align='left',histtype='stepfilled')
# Out:
# (array([3., 0., 3., 0., 3., 0., 1., 0., 3., 1.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  [<matplotlib.patches.Polygon at 0x1a1ed44e750>])

# %%
# Box Plot
data=np.array([0,5,6,20,15])

plt.boxplot(data,vert="None", patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a1ed5ba150>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a1ed689650>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1a1ebcebc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1ed68a4d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1ed68acd0>],
#  'means': []}

# %%
# Box Plot
data=[np.random.normal(0,std,100) for std in range (1,4)]
plt.boxplot(data,vert="None", patch_artist=True)
data
# Out:
# [array([-2.91748309e+00,  1.93839636e+00,  1.72403273e-01,  1.69405095e-03,
#         -1.05821262e+00,  9.38888263e-01,  1.34945642e+00,  3.58127386e-03,
#          1.34366637e+00, -1.51031680e+00,  1.53382603e+00, -1.68684541e+00,
#         -1.08275272e+00, -5.66855712e-01, -2.32995427e-01, -7.34037853e-01,
#         -1.64026129e+00,  5.27884618e-01, -1.00766799e+00, -9.51864386e-01,
#          2.58904898e-01, -3.27053399e-01,  1.20172343e-01,  6.17760647e-01,
#         -4.16107409e-01, -8.01124410e-02,  5.00702922e-01,  2.20508382e-01,
#         -2.12528405e-01,  1.86699122e-01, -4.85688610e-01,  1.67104017e+00,
#          1.79268210e+00, -5.27341218e-01,  6.27980323e-01,  1.47932683e+00,
#         -1.59731277e+00, -1.61636634e+00, -1.92065499e+00,  3.52839289e-01,
#         -6.53918848e-01,  1.64700982e+00,  8.37811017e-01,  1.48804740e+00,
#         -1.67802176e+00,  2.28686928e+00, -1.61278102e+00,  9.10124714e-01,
# ...

# %%
# Pie Chart
labels="Python", "C++", "Ruby", "Java"
sizes=[200,300,100,250]
colors=["gold", "red", "blue", "green"]
explode=(0,0,0,0)
plt.pie(sizes, labels=labels, explode=explode, colors=colors, shadow=True, autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.0999999999999999, 1.1, -1.099998860169429, 1.099999308463382)
