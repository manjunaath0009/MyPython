# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline 
# %reload_ext autoreload
# %autoreload 2

# %%
cs_df = pd.read_csv("data.csv")
cs_df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset("car_crashes")
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
# Distribution Plot - DEPRECATED
sns.displot(df['not_distracted'], kde=True, bins=50, color='r')
# Out:
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Joint Plot

sns.jointplot(x="speeding", y="alcohol", data=df, kind='hex')

#kind: 'scatter', 'kde', 'hist', 'hex'
# Out:
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# KDE Plot

sns.kdeplot(df["alcohol"])
# Out:
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
# Pair Plot

sns.pairplot(df)
# Out:
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
tips_df=sns.load_dataset("tips")
print(tips_df)
sns.pairplot(tips_df, hue="sex", palette="Reds")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
# Rug Plot
print(tips_df.info())
sns.rugplot(tips_df['tip'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None
# d:\PythonExamples\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tip'>

# %%
sns.set_style('white')
sns.lmplot(x="total_bill", y="tip", col="sex", row="time", data=tips_df)

# %%
# Distplot stands for distribution plot, it takes as input an array and plots a curve corresponding to the distribution of points in the array.

# Normal : The Normal Distribution is one of the most important distributions. It is also called the Gaussian Distribution after the German mathematician Carl Friedrich Gauss. It fits the probability distribution of many events, eg. IQ Scores, Heartbeat etc.

# Binomial : Binomial Distribution is a Discrete Distribution. It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails. It has three parameters: n - number of trials. p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each). size - The shape of the returned array.

# Poison : Poisson Distribution is a Discrete Distribution. It estimates how many times an event can happen in a specified time. e.g. If someone eats twice a day what is the probability he will eat thrice?

# Uniform : Used to describe probability where every event has equal chances of occuring. E.g. Generation of random numbers.

# Logistic : Logistic Distribution is used to describe growth. Used extensively in machine learning in logistic regression, neural networks etc.

# Multinomial: Multinomial distribution is a generalization of binomial distribution. It describes outcomes of multi-nomial scenarios unlike binomial where scenarios must be only one of two. e.g. Blood type of a population, dice roll outcome.

# Exponential: Exponential distribution is used for describing time till next event e.g. failure/success etc.

# Chi Square: Chi Square distribution is used as a basis to verify the hypothesis.

# Rayleigh: Rayleigh distribution is used in signal processing.

# Pareto : A distribution following Pareto's law i.e. 80-20 distribution (20% factors cause 80% outcome).

# Zipf distributions are used to sample data based on zipf's law.

# S E A B O R N

# Distribution : distplot, joinplot, pairplot

# %%
# DISTPLOT
print(sns.get_dataset_names())
df=sns.load_dataset("tips")
df.head(5)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
# ...

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
plt.figure(figsize = (8, 6))

corr = df.select_dtypes(['float64', 'int64']).corr()

sns.heatmap(corr)
# Out:
# <Axes: >

# %%
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips_df, hue="sex")

# %%
sns.pairplot(tips_df, hue="smoker")

print(df['smoker'].value_counts())
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
# Categorical Plots : boxplot, violinplot, countplot, barplot
tips_df=sns.load_dataset("tips")
tips_df

#https://www.geeksforgeeks.org/countplot-using-seaborn-in-python/

sns.countplot(x='sex',data=tips_df)

# %%
sns.countplot(x='sex',data=tips_df, hue="smoker")
plt.xlabel('SEX')
plt.ylabel('NUMBER OF COUNTS')
# Out:
# Text(0, 0.5, 'NUMBER OF COUNTS')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#create some fake data
df = pd.DataFrame({'quarter': ['Q1', 'Q2', 'Q3', 'Q4'],
                   'sales': [23, 26, 24, 34]})

#create seaborn barplot
ax = sns.barplot(x='quarter', y='sales', 
                 data = df, 
                 color='steelblue')

#specfiy axis labels
plt.xlabel('Sales Quarter', size=16, fontstyle='italic', weight=900)
plt.ylabel('Total Sales', size=16, family='monospace')
plt.title('Sales by Quarter')

#display barplot
plt.show()

# %%
# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
# Categorical Plots : boxplot, violinplot, countplot, barplot
tips_df=sns.load_dataset("tips")
tips_df

#https://www.geeksforgeeks.org/countplot-using-seaborn-in-python/

sns.barplot(y='total_bill',x="sex",data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(y='tip',x="sex",data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(y='tip',x="sex",data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(y='total_bill',x="day",hue="smoker",data=tips_df, palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(y='total_bill',x="day",data=tips_df, palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
Iris=sns.load_dataset("iris")
Iris
Iris.info()

# ***.info ****************
# ***.dtypes
# corr : corr = ***.select_dtypes(['float64', 'int64']).corr()

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# ***.info ****************
Iris.dtypes
# corr : corr = ***.select_dtypes(['float64', 'int64']).corr()

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# ***.info ****************
# Iris.dtypes
Iris.select_dtypes('float64').corr()
corr=Iris.select_dtypes('float64').corr()
print(corr)
sns.heatmap(corr)

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
# <Axes: >

# %%
# ***.info ****************
# Iris.dtypes
# Iris.select_dtypes('float64').corr()
# corr=Iris.select_dtypes('float64').corr()
# print(corr)
# sns.heatmap(corr)

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
sns.jointplot(x="sepal_width", y="sepal_length", data=Iris, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')

# %%
# ***.info ****************
# Iris.dtypes
# Iris.select_dtypes('float64').corr()
# corr=Iris.select_dtypes('float64').corr()
# print(corr)
# sns.heatmap(corr)

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
# sns.jointplot(x="sepal_width", y="sepal_length", data=Iris, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")
sns.pairplot(Iris, hue="sepal_width", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')

# %%
# ***.info ****************
# Iris.dtypes
# Iris.select_dtypes('float64').corr()
# corr=Iris.select_dtypes('float64').corr()
# print(corr)
# sns.heatmap(corr)

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
# sns.jointplot(x="sepal_width", y="sepal_length", data=Iris, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")
# sns.pairplot(Iris, hue="sepal_width", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
sns.boxplot(data=Iris)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')
# Out:
# <Axes: >

# %%
# ***.info ****************
# Iris.dtypes
# Iris.select_dtypes('float64').corr()
# corr=Iris.select_dtypes('float64').corr()
# print(corr)
# sns.heatmap(corr)

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
# sns.jointplot(x="sepal_width", y="sepal_length", data=Iris, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")
# sns.pairplot(Iris, hue="sepal_width", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
# sns.boxplot(data=Iris)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
sns.countplot(data=Iris)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')
# Out:
# <Axes: ylabel='count'>

# %%
# ***.info ****************
# Iris.dtypes
# Iris.select_dtypes('float64').corr()
# corr=Iris.select_dtypes('float64').corr()
# print(corr)
# sns.heatmap(corr)

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
# sns.jointplot(x="sepal_width", y="sepal_length", data=Iris, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")
# sns.pairplot(Iris, hue="sepal_width", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
# sns.boxplot(data=Iris)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
# sns.countplot(data=Iris)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
sns.barplot(data=Iris)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')
# Out:
# <Axes: >

# %%
# ***.info ****************
# Iris.dtypes
# Iris.select_dtypes('float64').corr()
# corr=Iris.select_dtypes('float64').corr()
# print(corr)
# sns.heatmap(corr)

# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - sns.jointplot(x="speeding", y="alcohol", data=***, kind='hex')
# sns.jointplot(x="sepal_width", y="sepal_length", data=Iris, kind='hex')
# Distribution : PAIRPLOT - sns.pairplot(***, hue="sex", palette="Reds")
# sns.pairplot(Iris, hue="sepal_width", palette="Reds")

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - sns.boxplot(y='tip',x="sex",data=***)
# sns.boxplot(data=Iris)
# Categorical : COUNTPLOT - sns.countplot(x='sex',data=***)
# sns.countplot(data=Iris)
# Categorical : BARPLOT - sns.barplot(y='total_bill',x="sex",data=***)
# sns.barplot(data=Iris)
# Categorical : VIOLINPLOT - sns.violinplot(y='total_bill',x="day",data=***, palette='rainbow')
sns.violinplot(data=Iris, palette='rainbow')
# Out:
# <Axes: >

# %%
# Distribution Plots (integer and floting values) : distplot, joinplot, pairplot; 
#-----------------------------------------------------------
# Distribution : DISTPLOT  - Deprecated
# Distribution : JOINTPLOT - Draw a plot of two variables with bivariate and univariate graphs.
# Distribution : PAIRPLOT - Plot pairwise relationships in a dataset.

# Categorical Plots : boxplot, violinplot, countplot, barplot
# -------------------------------------------------------------
# Categorical : BOXPLOT - Draw a box plot to show distributions with respect to categories.
# Categorical : COUNTPLOT - Show the counts of observations in each categorical bin using bars.
# Categorical : BARPLOT - Show point estimates and errors as rectangular bars.
# Categorical : VIOLINPLOT - Draw a patch representing a KDE and add observations or box plot statistics.
