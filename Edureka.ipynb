# %%
#https://www.youtube.com/playlist?list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe

https://www.youtube.com/watch?v=-ETQ97mXXF0

from logging import Manager
from platform import architecture
from typing import Required
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from random import randint
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline 
# %reload_ext autoreload
# %autoreload 2

colors = ['#37AB65', '#3DF735', '#AD6D70', '#EC2504', '#8C0B90', '#C0E4FF', '#27B502', '#7C60A8', '#CF95D7', '#145JKH']

# https://www.youtube.com/playlist?list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe

# https://www.youtube.com/watch?v=-ETQ97mXXF0

Data Science : Statistics, Programming Language, Data Extraction and Processing, Data Wrangling and Exploration (Cleaning), Machine Learning, Big Data Frameworks, Visualization

Upskilling Required
Machine Learning - Algorithms

Tools :
    
    Data Visualization - Diablo, Power BI
    
Roles in Data Science :
    Data Scientist  -   Matlab, SQL, Python and other (Mathematics)
    Data Analyst - Visualization (Queries), Create and Modify Algorithms - SQL, SAS, Python
    Data Architect - Blueprints, Data Warehousing, Data Modelling, Extraction Transformation
    Data Engineer - Test Scalable Big Data System
    Statistician
    DB Administration
    Business Analyst
    Data & Analytics Manager 

Data Life Cycle : 
    Business Requirements
    Data Acquisition
    Data Processing
    Data Exploration
    Modelling
    Deployment    
    
Statistics and Probability

Data - (a) Qualitative (b) Quantitative
(a) Qualitative : Nominal (e.g., Table has Gender/Race it also called Unordered) and Ordinal (e.g., Table has Customer ID with Rating, it also called Ordered)
(b) Quantitative : Discrete (Finite number of possible values, e.g., Number of Student in a class) and continuous (infinite number of possible values, e.g., Weight of a person)

Statistics are area of applied mathematics with the data collection, analysis, interpretation and presentation

https://www.youtube.com/watch?v=11unm2hmvOQ
https://www.youtube.com/watch?v=Ims3L_hfLJU
https://www.youtube.com/watch?v=y1y1ATTMpaw

https://www.youtube.com/watch?v=PbguWyuZ4Ts


https://www.youtube.com/watch?v=cGez1q4iOFU

https://github.com/krishnaik06/The-Grand-Complete-Data-Science-Materials/tree/main

https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay

# %%
from turtle import ScrolledCanvas


Mean, Median, Mode 

Descriptive Stats
------------------
1. Gaussian Distribution 
2. LogNormal Distribution 
3. Binomial Distribution 
4. Standard Normal Distribution 
5. Transformation and Standardization 
6. Q-Q Plot
7. How to determine 

Infential Stats
----------------
Z test 
t test 
ANOVA
CHISQUARE
HYPOTHESIS (P Value)
Confidence Interval 


Statistics is the science of collecting, organizing and analyzing data. Using for better decision making 

Types : DESCRPTIVE (It consists of organizing and summarizing of data), INFENTIAL (It is a technique where in we used that we have measured to form conclusion) 

Descriptive : Average marks of the students in a class
Infential : Is the marks are similar to all the sections 

Simple Random Sampling: Everyone has a chance to get selected 
Stratified Sampling : Male/Female (Groupings)
Systematic Sampling : Every selected person to do survey 
Convenient Sampling : Whoever expert in any programming language 

Variable : Property has any value 

2 Kinds of Variable : Quantitative and Qualitative

Quantitative : Measured Numerically (Age, Weight and Height)
Qualitative : Gender (Male and Female)

Quantitative : Discrete Variable and Continuous Variable

Discrete Variable (categorical): Whole number (no. of bank accounts of person, no. of children in a family)
Continuous Variable :Any value (height, weight, Rainfall, Temperature )

Variable Measurement Scales 
4 Types : Nominal, Ordinal, Interval, Ratio 

Nominal : Categorical Data (e.g., Gender, Color) 
Ordinal : Order of the data matters but value does not 
Interval : Order and Value also matters (Temperature)
Ratio : Male or Female

Frequency Distribution : Values of different category 


Meaure of Central Tendency
Measure of Dispersion 
Gausian Distribution
Z Score 
Standard Normal Distribution 

Arithmatic Mean - Mean (Average)
Central Tendency (Mean, Median, Mode)

Mean = N/n = Number of Frequencies / Total Number of Frequencies 

Measure of Dispersion : Variance and Standard Deviation 
Variance : (a) Center of Tendency : rho(square) = summation of (x<sub>i</sub> - mu)<sup>2</sup> / N
(b) Std Deviation : Sigma = Square root of Variance      
 
 Percentile and Quartiles
 

Percentile : 
    {1,2,3,4,4,5,6,7,7,7,8,8,8,8,8,8,8,8,11,12}
    let x=12, n=20 (Number of value below x / n)*100
    (18/20)*100 = 90%

Find the value using Percentile = (Percentile/100)*(n+1)

Five Number Summary
    Minimum
    First Quartile
    Median
    Second Quartile
    Maximum 
    
{1,2,2,3,3,4,5,5,5,6,6,6,6,7,8,8,9,27}
